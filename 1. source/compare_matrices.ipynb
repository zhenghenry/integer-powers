# %%
import h5py
import numpy as np

# %%
john_b222 = np.array(h5py.File('../B222_Jfunc_0.012_0.0232_0.1561_new.h5', 'r')['jmat'])
my_b222 = np.array(h5py.File('../B222_Jfunc_0.012_0.0232_0.1561_.h5', 'r')['jmat'])
john_b222_v4 = np.array(h5py.File('../v4_B222_Jfunc_0.012_0.0232_0.1561_.h5', 'r')['jmat'])
# Out:
# /var/folders/0l/yhd8zfz942g5sqxbrcz6wmx40000gn/T/ipykernel_59285/1943626414.py:1: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   john_b222 = np.array(h5py.File('../B222_Jfunc_0.012_0.0232_0.1561_new.h5', 'r')['jmat'])
# /var/folders/0l/yhd8zfz942g5sqxbrcz6wmx40000gn/T/ipykernel_59285/1943626414.py:2: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   my_b222 = np.array(h5py.File('../B222_Jfunc_0.012_0.0232_0.1561_.h5', 'r')['jmat'])
# /var/folders/0l/yhd8zfz942g5sqxbrcz6wmx40000gn/T/ipykernel_59285/1943626414.py:3: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   john_b222_v4 = np.array(h5py.File('../v4_B222_Jfunc_0.012_0.0232_0.1561_.h5', 'r')['jmat'])

# %%
john_to_me_ind = np.array([80, 77, 78, 79, 68, 69, 70, 67, 71, 72, 60, 61, 59, 58, 62, 64, 63, \
57, 65, 66, 6, 9, 5, 1, 7, 4, 11, 3, 8, 13, 12, 10, 2, 14, 15, 82, \
47, 44, 40, 46, 43, 49, 38, 45, 42, 53, 51, 39, 48, 54, 76, 52, 50, \
41, 55, 56, 84, 81, 83, 18, 26, 23, 30, 17, 25, 22, 32, 28, 16, 24, \
21, 74, 34, 29, 19, 27, 35, 75, 73, 33, 31, 20, 36, 37])-1

# %%
np.allclose(john_b222, my_b222, rtol=1e-2)
# Out:
# True

# %%
np.allclose(john_b222, my_b222[john_to_me_ind], rtol=1e-2)
# Out:
# True

# %%
john_b222 - my_b222
# Out:
# array([[[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           -2.01948392e-28,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00, -1.61558713e-27,  7.88860905e-31, ...,
#            0.00000000e+00,  1.97215226e-31,  4.93038066e-32],
#          ...,
#          [-2.01948392e-28,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  6.31088724e-30],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  1.75162308e-46]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  2.52435490e-29],
# ...
